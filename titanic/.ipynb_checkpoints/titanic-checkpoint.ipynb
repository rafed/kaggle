# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# ### Useful stuff that can show various summaries about data

# %%
# train.info()
train.head()
# train.size
# train.shape
# train.describe()
# train.describe(include=['O'])
# test.isnull().sum()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Relationship between Features and Outcome

# %%
survived = train[train['Survived'] == 1]
not_survived = train[train['Survived'] == 0]

print ("Survived: %i (%.1f%%)"%(len(survived), float(len(survived))/len(train)*100.0))
print ("Not Survived: %i (%.1f%%)"%(len(not_survived), float(len(not_survived))/len(train)*100.0))
print ("Total: %i"%len(train))
# Out:
# Survived: 342 (38.4%)
# Not Survived: 549 (61.6%)
# Total: 891

# %% [markdown]
# #### Pclass and Survival

# %%
train.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train.groupby('Pclass').Survived.value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
# pclass = train.pivot_table(index="Pclass", values="Survived")
# pclass.plot.bar()
# plt.show()

sns.barplot(x="Pclass", y="Survived", data=train)

# %% [markdown]
# #### Gender and Survival

# %%
sns.barplot(x='Sex', y='Survived', data=train)

# %%
sns.factorplot(x='Pclass', y='Survived', hue='Sex', col='Embarked', data=train)
# Out:
# /home/red/.local/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.barplot(x='Parch', y='Survived', ci=None, data=train) # ci=None will hide the error bar

# %% [markdown]
# #### Age and Survival

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

sns.violinplot(x="Embarked", y="Age", hue="Survived", data=train, split=True, ax=ax1)
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train, split=True, ax=ax2)
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train, split=True, ax=ax3)

# %%
plt.figure(figsize=(15,6))
sns.heatmap(train.drop('PassengerId',axis=1).corr(), vmax=0.6, square=True, annot=True)

# %% [markdown]
# #### Joining train and test so that common operations can be done together

# %%
train_test_data = [train, test] # combining train and test dataset

for dataset in train_test_data:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.')
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
    # dataset['Embarked'] = dataset['Embarked'].astype("category").cat.codes

    # Age stuff
    cut_points = [-1,0, 5, 12, 18, 35, 60, 100]
    label_names = ["Missing", 'Infant', "Child", 'Teenager', "Young Adult", 'Adult', 'Senior']
    
    dataset["Age"] = dataset["Age"].fillna(-0.5)
    dataset["Age_categories"] = pd.cut(dataset["Age"],cut_points,labels=label_names)
    
    dataset.loc[ dataset['Age'] <= 5, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 5) & (dataset['Age'] <= 12), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 12) & (dataset['Age'] <= 18), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 18) & (dataset['Age'] <= 35), 'Age'] = 3
    dataset.loc[(dataset['Age'] > 35) & (dataset['Age'] <= 60), 'Age'] = 4
    dataset.loc[ dataset['Age'] > 60, 'Age'] = 5
    
    # Title stuff (Mr/Miss/Master...)
    dataset['Title'] = dataset['Title'].astype("category").cat.codes
    
    # Fare sruff
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

# %%
sns.barplot(x="Age_categories", y="Survived", data=train)

# %%
#train.Embarked.unique()
train.Embarked.value_counts()
# Out:
# 0    646
# 1    168
# 2     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### Feature selection

# %%
# features_drop = ['Name', 'SibSp', 'Parch', 'Ticket', 'Cabin']
# train = train.drop(features_drop, axis=1)
# test = test.drop(features_drop, axis=1)
# train = train.drop(['PassengerId', 'AgeBand', 'FareBand'], axis=1)

# selected features
features = ["Pclass", "Sex", "Age", "Fare", "Embarked", "Title"]

train_x = train[features]
train_y = train["Survived"] # use .copy() maybe??
test_x = test[features]

train_x.shape, train_y.shape, test_x.shape
# Out:
# ((891, 6), (891,), (418, 6))

# %% [markdown]
# ### Classification and accuracy

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier

models = []
models.append(('LR', LogisticRegression()))
models.append(('SVC', SVC()))
models.append(('LinSVC', LinearSVC()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DTR', DecisionTreeClassifier()))
models.append(('RFR', RandomForestClassifier()))
models.append(('GAU', GaussianNB()))
models.append(('NN', Perceptron()))
models.append(('SGD', SGDClassifier()))

# %%
from sklearn import model_selection

scoring = 'balanced_accuracy' #'neg_mean_squared_error'
kfold = model_selection.KFold(n_splits=10, random_state=10)

for name, model in models:
    results = model_selection.cross_val_score(model, train_x, train_y, scoring=scoring, cv=kfold)
    print("Model name: " + name)
    print("Accuracy:",results.mean()*100)
    print()    
#     print("Mean: "+ str(rmseScores.mean()))
#     print("Standard deviation: " + str(rmseScores.std()))
# Out:
# Model name: LR
# Accuracy: 75.4049524225
# Model name: SVC
# Accuracy: 76.8975288291
# Model name: LinSVC
# Accuracy: 73.3661727918
# Model name: KNN
# Accuracy: 74.1433509567
# Model name: DTR
# Accuracy: 79.6703149687
# Model name: RFR
# Accuracy: 79.6787924839
# Model name: GAU
# Accuracy: 75.8302909232
# Model name: NN
# Accuracy: 68.500634282
# Model name: SGD
# Accuracy: 59.4761244843
